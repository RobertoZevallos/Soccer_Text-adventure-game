# %%
# Roberto Zevallos - Text Adventure Game.v3
# Dec-12-2021
# v3:
# - abbreviation of code syntax
# - use of time.sleep funtion to reduce number of "Please press Enter/Intro to continue"

"""This game is based on a famous soccer match played in December 2014 in
Ecuador, known as “The Match of the Century”. This match was the final game
between two of the biggest teams in Ecuador. It was a two-legged tie where the
winning team was determined by aggregate score, the sum of the scores of both legs.

The first leg was played at “Monumental”, Barcelona’s stadium, and the second
leg at “Capwell”, Emelec’s Stadium. The first leg ended Barcelona 1-1 Emelec,
and the second leg ended Emelec 3-0 Barcelona.

During this text adventure game, you will recreate the most iconic plays of the
second leg by representing one of the two MVPs of Emelec. To win the game, you
must win by a score of 3-0 to become the champion of the 2014 Ecuadorean tournament.

For further reference of the match: https://youtu.be/s9S8xp0stVA

Known bugs and or errors:
None."""

# importing required package
import time

# Introduction to understand what will be required
print("""Dear player, thank you for joining the “The Match of the Century” game.
In this game you will represent one of the two MVPs of Emelec to recreate the
most iconic plays of the second leg played in the final between Barcelona and
Emelec in the year 2014 at "Estadio Capwell".

To complete this game, you must win by a score of 3-0 and become the champion
of the 2014 Ecuadorean tournament!!

Good luck :)""")

# defining function to select a player
def player_selection():
    print("""First you need to select a player to try to win this match!\n""")
    input(prompt = "Please press Enter/Intro to begin\n")
    
    # variable to save player selected and use it in conditional
    player = input(prompt = """Please select your player:
    a. Ángel "El ángel del gol" Mena -- Position: Winger
    b. Miller "Killer" Bolaños       -- Position: Center Forward
    Your answer: """)
    
    # list of the most common ways to type "Ángel Mena" for user input validation
    # "_m" is used to identify all of the variables related to Angel Mena
    angel_m_answers = ['ángel mena', 'angel mena', 'ángel "el ángel del gol" mena',
                       'angel "el ángel del gol" mena', 'ángel "el angel del gol" mena',
                       'angel "el angel del gol" mena','el ángel del gol', 'el angel del gol',
                       'winger', 'ángel', 'angel', 'mena']
    
    # list of the most common ways to type "Miller Bolaños" for user input validation
    # "_b" is used to identify all of the variables related to Miller Bolaños
    miller_b_answers = ['miller bolaños', 'miller bolanos', 'miller bola;os',
                        'miller "killer" bolaños', 'miller "killer" bolanos', 'miller "killer" bola;os',
                        'killer', 'miller', 'bolaños', 'bolanos', 'bola;os', 'center forward',
                        'forward']
    
    # .lower used to receive either capital or non capital letters as valid input
    if player.lower() == 'a.' or player.lower() == 'a' or player.lower() in angel_m_answers:

        print("""\nGreat choice!
You will be playing as Ángel "El ángel del gol" Mena.
Winger from Club Sport Emelec.""")
        
        time.sleep(2) # pausing 2 seconds before advancing
        angel_m_1() # takes the game to the next stage based on option a
    
    # .lower used to receive either capital or non capital letters as valid input
    elif player.lower() == 'b.' or player.lower() == 'b' or player.lower() in miller_b_answers:
        
        print("""\nGreat choice!
You will be playing as Miller "Killer" Bolaños.
Center Forward from Club Sport Emelec.""")
        
        time.sleep(2) # pausing 2 seconds before advancing
        miller_b_1() # takes the game to the next stage based on option b
    
    else:
        print("That was an invalid entry. Please try again.\n")
        player_selection() # runs function from beginning.

# defining the function for the first play as Angel Mena
def angel_m_1():
    print("""
It is minute 20:30 of the match and you see that a teammate enters the penalty
box and is close to scoring a goal, but he gets hit by the rival team’s
goalkeeper. You can see that the referee is going to call a penalty, but you
also notice that the ball is coming towards you...""")
    
    time.sleep(3) # pausing 3 seconds before advancing
    
    # variable for first Mena's goal
    goal_m_1 = input(prompt = """What do you do?\n
    a. Wait for the referee to call the penalty.\n
    b. Get the ball and shoot to goal.\n
    c. Pass the ball to another teammate outside of the penalty box.\n
    Your answer: """)
    
    if goal_m_1.lower() == 'a.' or goal_m_1.lower() == 'a' or 'wait' in goal_m_1.lower() or 'penalty' in goal_m_1.lower():
        print("""\nThe referee calls the penalty and you shoot it!!
However, you miss the penalty and the coach decides to substitute you...
You can’t continue playing and your team loses the game :(\n""")
        fail() # player loses game
        
    elif goal_m_1.lower() == 'b.' or goal_m_1.lower() == 'b' or 'shoot' in goal_m_1.lower() or 'get' in goal_m_1.lower():
        print('AMAZING!! You just scored a goal and the match is now 1-0')
        
        # start a nested conditional to see if user wants to celebrate
        # while True used to bring user back to this point if they enter an invalid answer
        while True:                
            celebration_m = input(prompt = """Do you want to celebrate the goal?
a. Yes
b. No
Your answer: """)
            if celebration_m.lower() == 'a.' or celebration_m.lower() == 'a' or 'yes' in celebration_m.lower() or celebration_m.lower() == 'y' :
                # importing random package to generate a different celebration each time
                import random
                
                # 3 different celebrations can occur if the game is played multiple times
                celebration_option_m = random.randint(a = 1, b = 3)
                
                if celebration_option_m == 1:
                    print("""
                
            
 ██████╗  ██████╗  █████╗ ██╗     ██╗██╗██╗
██╔════╝ ██╔═══██╗██╔══██╗██║     ██║██║██║
██║  ███╗██║   ██║███████║██║     ██║██║██║
██║   ██║██║   ██║██╔══██║██║     ╚═╝╚═╝╚═╝
╚██████╔╝╚██████╔╝██║  ██║███████╗██╗██╗██╗
 ╚═════╝  ╚═════╝ ╚═╝  ╚═╝╚══════╝╚═╝╚═╝╚═╝
 
 
███╗   ███╗███████╗███╗   ██╗ █████╗ ██╗
████╗ ████║██╔════╝████╗  ██║██╔══██╗██║
██╔████╔██║█████╗  ██╔██╗ ██║███████║██║
██║╚██╔╝██║██╔══╝  ██║╚██╗██║██╔══██║╚═╝
██║ ╚═╝ ██║███████╗██║ ╚████║██║  ██║██╗
╚═╝     ╚═╝╚══════╝╚═╝  ╚═══╝╚═╝  ╚═╝╚═╝                                          
""")
                
                elif celebration_option_m == 2:
                    print("""                                         
  ____  ___   ___   ___  _       _____ ____   ___  __  __ 
 / ___|/ _ \ / _ \ / _ \| |     |  ___|  _ \ / _ \|  \/  |
| |  _| | | | | | | | | | |     | |_  | |_) | | | | |\/| |
| |_| | |_| | |_| | |_| | |___  |  _| |  _ <| |_| | |  | |
 \____|\___/ \___/ \___/|_____| |_|   |_| \_\\___/|_|  |_|
                                                                                                                   
 _____ _          _    _   _  ____ _____ _                
| ____| |        / \  | \ | |/ ___| ____| |               
|  _| | |       / _ \ |  \| | |  _|  _| | |               
| |___| |___   / ___ \| |\  | |_| | |___| |___            
|_____|_____| /_/   \_|_| \_|\____|_____|_____|           
                                                                                                                  
 ____  _____ _        ____  ___  _     _                  
|  _ \| ____| |      / ___|/ _ \| |   | |                 
| | | |  _| | |     | |  _| | | | |   | |                 
| |_| | |___| |___  | |_| | |_| | |___|_|                 
|____/|_____|_____|  \____|\___/|_____(_)                 
                                                          
""")
                    
                elif celebration_option_m == 3:
                    print("""
   __________  __       __________  __       __________  __       ______
  / ____/ __ \/ /      / ____/ __ \/ /      / ____/ __ \/ /      / / / /
 / / __/ / / / /      / / __/ / / / /      / / __/ / / / /      / / / / 
/ /_/ / /_/ / /___   / /_/ / /_/ / /___   / /_/ / /_/ / /___   /_/_/_/  
\____/\____/_____/   \____/\____/_____/_  \____/\____/_____/  (_|_|_)   
   /  |/  / ____/ | / /   |  /   |  /   |     / / / /                   
  / /|_/ / __/ /  |/ / /| | / /| | / /| |    / / / /                    
 / /  / / /___/ /|  / ___ |/ ___ |/ ___ |   /_/_/_/                     
/_/  /_/_____/_/ |_/_/  |_/_/  |_/_/  |_|  (_|_|_)                      
                                                                        
""")
                    
                else:
                    print("Something went wrong, please answer the question again.")
                    continue # code gets here if something fails and stays in the while until it is fixed
                
                angel_m_2()
                break # takes the game to the next stage after celebrating.
            
            elif celebration_m.lower() == 'b.' or celebration_m.lower() == 'b' or 'no' in celebration_m.lower() or celebration_m.lower() == 'n' :
                print("That's ok, the fans understand you are really focused on winning the game.")
                angel_m_2()
                break # takes the game to the next stage without celebrating.
        
            else:
                print("""\nThat was an invalid entry. Please try again.
It is ok if you only enter letters as "a" or "b".\n""")
                continue # ask user again if they want to celebrate until they get a correct answer.
                
        # end of nested conditional
        
    elif goal_m_1.lower() == 'c.' or goal_m_1.lower() == 'c' or 'pass' in goal_m_1.lower() or 'teammate' in goal_m_1.lower():
        print("""\nOh no, you miss the pass, and the rival team gets the ball.
The coach decides to substitute you...
You can’t continue playing and your team loses the game :(\n""")
        fail() # player loses the game
        
    else:
        print("\nThat was an invalid entry. Please try again.") # the line break at the beginning gives me a nice organization of the text
        angel_m_1() # runs function from beginning.

# defining the function for the second play as Angel Mena
def angel_m_2():
    print("""
It is now minute 80:00 of the match and you are winning 1-0.
You are standing on the left outer side of the penalty box and receive the
ball. You can see 3 of your teammates inside the penalty box and a defender
coming towards you...""")

    time.sleep(3) # pausing 3 seconds before advancing
    
    # variable for first Mena's assist
    assist_m_1 = input(prompt = """What do you do?\n
    a. Center the ball to the first teammate.\n
    b. Center the ball to the second teammate.\n
    c. Center the ball to the third teammate.\n
    d. Run to your left and dribble the defender.\n
    Your answer: """)
    
    if assist_m_1.lower() == 'a.' or assist_m_1.lower() == 'a' or 'first' in assist_m_1.lower() or assist_m_1.lower() == 'center the ball to the first teammate.':
        print("""\nYour teammate gets the ball and shoots, but the rival’s goalkeeper
catches the ball and rapidly plays with his teammates and they score the tying goal.
The game ends 1-1 and it goes to a penalty shootout.
However, your team is too nervous and you lose the game.""")
        fail() # player loses the game
    
    elif assist_m_1.lower() == 'b.' or assist_m_1.lower() == 'b' or 'second' in assist_m_1.lower() or assist_m_1.lower() == 'center the ball to the second teammate.':
        print("""\nYour teammate didn’t expect the ball and the rival’s goalkeeper
catches the ball and rapidly plays with his teammates and they score the tying goal.
The game ends 1-1 and it goes to a penalty shootout.
However, your team is too nervous and you lose the game.""")
        fail() # player loses the game
        
    elif assist_m_1.lower() == 'c.' or assist_m_1.lower() == 'c' or 'third' in assist_m_1.lower() or assist_m_1.lower() == 'center the ball to the third teammate.':
        print("""\nYour teammate hits the ball with his head and scores a magnificent goal!!!.""")
        angel_m_3() # takes game to next stage.
        
    elif assist_m_1.lower() == 'd.' or assist_m_1.lower() == 'd' or 'run' in assist_m_1.lower() or 'dribble' in assist_m_1.lower():
        print("""\nYou dribble the defender, but the ball goes to long to your left and it leaves the field.
The coach doesn't like this, and decides to substitute you...
You can’t continue playing, the rival team manages to score
3 goals in the last 10 minutes and your team loses the game :(\n""")
        fail() # player loses the game
        
    else:
        print("\nThat was an invalid entry. Please try again.")
        angel_m_2() # runs function again from beginning.

# defining the function for the third play as Angel Mena
def angel_m_3():
    
    input(prompt = "Make the time pass by pressing Enter/Intro\n") # cool add to make the game more dynamic
    
    print("""
  _____ _      _        _             _          
 |_   _(_) ___| | __   | |_ ___   ___| | __      
   | | | |/ __| |/ /   | __/ _ \ / __| |/ /      
   | | | | (__|   < _  | || (_) | (__|   < _ _ _ 
   |_| |_|\___|_|\_( )  \__\___/ \___|_|\_(_|_|_)
                   |/                            
""")
    
    time.sleep(1) # pausing 1 second before advancing
    
    print("""
  _____ _      _        _             _          
 |_   _(_) ___| | __   | |_ ___   ___| | __      
   | | | |/ __| |/ /   | __/ _ \ / __| |/ /      
   | | | | (__|   < _  | || (_) | (__|   < _ _ _ 
   |_| |_|\___|_|\_( )  \__\___/ \___|_|\_(_|_|_)
                   |/                            
""")
    
    time.sleep(1) # pausing 1 second before advancing
    
    print("""
It is now minute 85:50 of the match and you are winning 2-0.
You receive the ball in the center circle of the field and see that next you
is Miller "Killer" Bolaños and 1 rival’s defender, they both begin running
towards the penalty box...""")

    time.sleep(3) # pausing 3 seconds before advancing

    print("""Hurry! You have to start sprinting in order to reach the penalty box...""")
    
    # declaration of the variable used as a control on the while loop
    # loop used to control if input is not an integer number bigger than 0
    sprint_control_m = 1
    
    # importing random package to generate a different number of sprints each time
    import random
    
    # if the game is played multiple times, 4 different number of sprints are expected
    rand_sprints_m = random.randint(a = 1, b = 4)
    
    while sprint_control_m > 0:
        # try/except inside loop to control input as an integer number bigger than 0
        try:
            sprints_m = int(input(prompt = """\nGuess how many times do you think you have to sprint?
Please enter an integer number between 1 and 4 (i.e. 1, 2, 3, 4).
Your number of sprints: """))
            
            if sprints_m == 0: # 0 is not a valid answer
                print("""\nUps, that was an invalid entry.
You must enter an integer number bigger than 0 between 1 and 4 (i.e. 1, 2, 3, 4).
Please try again.""")
                continue # used to stay in the while function because an integer bigger than 0 is needed
            
            elif sprints_m == rand_sprints_m: # guess is correct
                sprint_control_m -= 1
                
                print(f"""\nGood you guessed correctly!
Now to sprint you have to press Enter/Intro {sprints_m} times:""")
            
                while sprints_m > 0: # loop to complete sprints
                    input(prompt = "Sprint!!!")
                    sprints_m -= 1
                    
                break # to exit the while loop since sprints are complete, moves forward in the game
            
            elif sprints_m > 4: # controlling if guess is over maximum
                print(f"""\nThe maximum number of sprints is 4... So {sprints_m} is too high.
Please try again and enter an integer number between 1 and 4 (i.e. 1, 2, 3, 4).""")
                
            elif sprints_m < 0: # controlling if guess is under minimum
                print(f"""\nThe minimum number of sprints is 1... So {sprints_m} is too low and not even possible.
Please try again and enter an integer number between 1 and 4 (i.e. 1, 2, 3, 4).""")
            
            elif sprints_m < rand_sprints_m: # giving a hint to guess a bigger number
                print(f"""\nThat was close, but the number of sprints is bigger than {sprints_m}.
Please try again.""")
                
            elif sprints_m > rand_sprints_m: # giving a hint to guess a smaller number
                print(f"""\nThat was close, but the number of sprints is smaller than {sprints_m}.
Please try again.""")
        
        except: # for this project is not necessary to include the "ValueError", but for the future it could be used here
            print("""\nUps, that was an invalid entry.
You must enter an integer number between 1 and 4 (i.e. 1, 2, 3, 4).
Please try again""")
    
    print("""
Good!! You have entered the penalty box and you see on your close left a
rival’s defender, on your far left Miller "Killer" Bolaños,
behind you another rival’s defender, and in front of you the rival’s goalkeeper.""")
       
    time.sleep(3) # pausing 3 seconds before advancing
    
    # variable for second Mena's assist
    assist_m_2 = input(prompt = """What do you do?\n
    a. Pass the ball to Miller "Killer" Bolaños.\n
    b. Dribble the goalkeeper and run to the goal line.\n
    c. Shoot right away from your current position.\n
    Your answer: """)
    
    if assist_m_2.lower() == 'a.' or assist_m_2.lower() == 'a' or 'pass' in assist_m_2.lower() or 'miller' in assist_m_2.lower() :
        print("""
   ____  ___    _    _     _        
  / ___|/ _ \  / \  | |   | |       
 | |  _| | | |/ _ \ | |   | |       
 | |_| | |_| / ___ \| |___|_|       
  \____|\___/_/   \_\_____(_)       
  _____            ___    _   _   _ 
 |___ /           / _ \  | | | | | |
   |_ \   _____  | | | | | | | | | |
  ___) | |_____| | |_| | |_| |_| |_|
 |____/           \___/  (_) (_) (_)
                                    
""")
        game_summary() # takes game to next and final stage.
    
    elif assist_m_2.lower() == 'b.' or assist_m_2.lower() == 'b' or 'dribble' in assist_m_2.lower() or 'run' in assist_m_2.lower():
        print("""You fail in your attempt and the goalkeeper gets the ball and rapidly plays with his teammates,
and they score a goal.
        
Everybody on your team blames you for this goal and you lose your mind and hit
a player from the other team and you get a red card.""")
        
        # start a nested conditional to see if user wants to fight
        
        # importing random package to generate a different number of punches each time 
        import random
        
        # if the game is played multiple times, different number of punches are expected
        punches_m = random.randint(a = 3, b = 6) # min 3 punches -- max 6
        
        # while True used to bring user back to this point if they enter an invalid answer
        while True:
            fight_m = input(prompt = """Do you want to continue fighting with other players?
            
a. Yes
        
b. No\n
Your answer: """)
        
            if fight_m.lower() == 'a.' or fight_m.lower() == 'a' or 'yes' in fight_m.lower() or fight_m.lower() == 'y' :
                print("""You begin a really big fight.""")
            
                while punches_m > 0:
                    input(prompt = f"Punch {punches_m} time(s) by pressing Enter/Intro ")
                    punches_m -= 1
                print("""\nThat was a bad choice, the game is suspended and you can't play for the team anymore.
            
You lose the game...\n""")
                fail() # player loses the game
                break # takes out of the while True and game continues
            
            elif fight_m.lower() == 'b.' or fight_m.lower() == 'b' or 'no' in fight_m.lower() or fight_m.lower() == 'n' :
                print("""Good choice to stop fighting.
However, since you got a red card you can't continue playing the game.\n""")
                fail()
                break # takes out of the while True and game continues
        
            else:
                print("""\nThat was an invalid entry. Please try again.
It is ok if you only enter letters as "a" or "b".\n""")
                continue # used to stay in the while function because an answer a or b is needed.
        # end of nested conditional
        
    elif assist_m_2.lower() == 'c.' or assist_m_2.lower() == 'c' or 'shoot' in assist_m_2.lower() :
        print("""You miss your shot, and the goalkeeper gets the ball and rapidly plays with his teammates,
and they score a goal.
        
Everybody on your team blames you for this goal and you lose your mind and hit
a player from the other team and you get a red card.

The rival team manages to score 2 goals in the last five minutes.
The game ends 2-2 and it goes to a penalty shootout.
However, your team is too nervous and you lose the game.""")
        fail() # player loses the game
        
    else:
        print("\nThat was an invalid entry. Please try again.")
        time.sleep(1) # pausing 1 seconds before advancing
        angel_m_3() # runs function again from beginning.

# defining the function for the first play as Miller Bolaños
def miller_b_1():
    print("""
It is minute 20:30 of the match and you see your attacking midfielder running
towards the penalty box and your winger already at the penalty box with a
defender right over him.
You have to decide to pass the ball to one of them or shoot directly to the goal..""")
    
    time.sleep(3) # pausing 3 seconds before advancing
    
    # variable for first Bolaños's assist
    assist_b_1 = input(prompt = """What do you do?\n
    a. Pass the ball to the winger.\n
    b. Pass the ball to the attacking midfielder.\n
    c. Shoot directly to goal.\n
    Your answer: """)
    
    if assist_b_1.lower() == 'a.' or assist_b_1.lower() == 'a' or 'winger' in assist_b_1.lower() :
        print("""\nThe winger gets the ball and shoots, but he misses the goal
because he received the ball in a complicated place on the penalty box. 
The coach and your teammates don't like this the coach decides to substitute you...
You can’t continue playing and your team loses the game :(\n""")
        fail() # player loses the game
        
    elif assist_b_1.lower() == 'b.' or assist_b_1.lower() == 'b' or 'attacking' in assist_b_1.lower() or 'midfielder' in assist_b_1.lower():
        print("""Amazing!! The attacking midfielder gets the ball and gets hit
by the rival’s goalkeeper and loses the ball. However, you winger, Ángel Mena,
manages to get the ball and scores a goal!
All of you feverishly celebrate with your fans and the match is now 1-0.""")
        miller_b_2() # takes player to next stage
        
    elif assist_b_1.lower() == 'c.' or assist_b_1.lower() == 'c' or 'shoot' in assist_b_1.lower() or 'goal' in assist_b_1.lower():
        print("""\nYou fail in your attempt and the goalkeeper gets the ball and rapidly plays
with his teammates, and they score a goal.
        
Everybody on your team blames you for this goal and you lose your mind and hit
a player from the other team and you get a red card.\n""")        
        
        # start a nested conditional to see if user wants to fight
        
        # importing random package to generate a different number of punches each time 
        import random
        
        # if the game is played multiple times, different number of punches are expected
        punches_b = random.randint(a = 3, b = 6) # min 3 punches -- max 6
        
        # while True used to bring user back to this point if they enter an invalid answer
        while True:
            fight_b = input(prompt = """Do you want to continue fighting with other players?
            
a. Yes
      
b. No\n
Your answer: """)
        
            if fight_b.lower() == 'a.' or fight_b.lower() == 'a' or 'yes' in fight_b.lower() or fight_b.lower() == 'y' :
                print("""You begin a really big fight.""")
            
                while punches_b > 0:
                    input(prompt = f"Punch {punches_b} time(s) by pressing Enter/Intro ")
                    punches_b -= 1
                print("""\nThat was a bad choice, the game is suspended and you can't play for the team anymore.
You lose the game...\n""")
                fail() # player loses the game
                break # takes out of the while True and game continues with fail function
            
            elif fight_b.lower() == 'b.' or fight_b.lower() == 'b' or 'no' in fight_b.lower() or fight_b.lower() == 'n' :
                print("""Good choice to stop fighting.
However, since you got a red card you can't continue playing the game.\n""")
                fail()
                break # takes out of the while True and game continues with fail function
        
            else:
                print("""\nThat was an invalid entry. Please try again.
It is ok if you only enter letters as "a" or "b".\n""")
                continue # used to stay in the while function because an answer a or b is needed.
        # end of nested conditional
        
    else:
        print("\nThat was an invalid entry. Please try again.") # the line break at the beginning gives me a nice organization of the text
        miller_b_1() # runs function again from beginning.

# defining the function for the second play as Miller Bolaños
def miller_b_2():
    input(prompt = "Make the time pass by pressing Enter/Intro\n") # cool add to make the game more dynamic
    
    print("""
  _____ _      _        _             _          
 |_   _(_) ___| | __   | |_ ___   ___| | __      
   | | | |/ __| |/ /   | __/ _ \ / __| |/ /      
   | | | | (__|   < _  | || (_) | (__|   < _ _ _ 
   |_| |_|\___|_|\_( )  \__\___/ \___|_|\_(_|_|_)
                   |/                            
""")
    
    time.sleep(1) # pausing 1 second before advancing
    
    print("""
  _____ _      _        _             _          
 |_   _(_) ___| | __   | |_ ___   ___| | __      
   | | | |/ __| |/ /   | __/ _ \ / __| |/ /      
   | | | | (__|   < _  | || (_) | (__|   < _ _ _ 
   |_| |_|\___|_|\_( )  \__\___/ \___|_|\_(_|_|_)
                   |/                            
""")
    
    time.sleep(1) # pausing 1 second before advancing
    
    print("""
It is now minute 80:00 of the match and you are winning 1-0.
Your winger has the ball on the left of the penalty box, and you see that he’s
looking to center the ball somewhere towards the penalty box.
You don’t know if he’s going to put the ball inside the goal box or right in
the penalty spot. You have to decide where to move.""")
   
    time.sleep(3) # pausing 3 seconds before advancing
    
    # variable for first Bolaños's goal
    goal_b_1 = input(prompt = """Where do you want to move?\n
    a. Move to the penalty spot.\n
    b. Run towards the goal box.\n
    Your answer: """)
    
    if goal_b_1.lower() == 'a.' or goal_b_1.lower() == 'a' or 'move' in goal_b_1.lower() or 'penalty' in goal_b_1.lower():
        print("""\nThe ball goes to the goal box and none of your teammates gets the ball.
The rival’s goalkeeper catches the ball and rapidly plays with his teammates, and they
score the tying goal. Your coach decides to substitute you. You can't continue playing
and a few minutes later Barcelona scores another goal, and you lose the game :(\n""")
        fail() # player loses the game
        
    elif goal_b_1.lower() == 'b.' or goal_b_1.lower() == 'b' or 'run' in goal_b_1.lower() or 'goal' in goal_b_1.lower():
        print("""\nAmazing the center goes right to your position in the goal box!!
You must decide if you want to shoot or pass the ball to another teammate.""")
        
        # start a nested conditional to see if user wants to shoot or pass the ball.
        # while True used to bring user back to this point if they enter an invalid answer
        while True:                
            decision_b = input(prompt = """What do you want to do?
a. Shoot a header.
b. Pass the ball to another teammate.\n
Your answer: """)
            if decision_b.lower() == 'a.' or decision_b.lower() == 'a' or 'shoot' in decision_b.lower() or 'header' in decision_b.lower() :
                print("""You shoot a magnificent header and score the 2-0:
   _____  ____          _        _ 
  / ____|/ __ \   /\   | |      | | 
 | |  __| |  | | /  \  | |      | | 
 | | |_ | |  | |/ /\ \ | |      | | 
 | |__| | |__| / ____ \| |____  |_| 
  \_____|\____/_/  __\_\______| (_) 
 |__ \            / _ \  | | | | | |
    ) |  ______  | | | | | | | | | |
   / /  |______| | | | | | | | | | |
  / /_           | |_| | |_| |_| |_|
 |____|           \___/  (_) (_) (_)
 
 """)
                
                miller_b_3()
                break # takes game to next stage after scoring a goal.
            
            elif decision_b.lower() == 'b.' or decision_b.lower() == 'b' or 'pass' in decision_b.lower() or 'teammate' in decision_b.lower() :
                print("""\nThe rival’s goalkeeper intercepts your pass and rapidly
plays with his teammates, and they score the tying goal.
Your coach decides to substitute you. You can't continue playing and a few minutes
later Barcelona scores another goal, and you lose the game :(\n""")
                fail()
                break # takes out of the while True and game continues with fail function.
        
            else:
                print("""\nThat was an invalid entry. Please try again.
It is ok if you only enter letters as "a" or "b".\n""")
                continue # ask the user again which play the want to do.
                
        # end of nested conditional
        
    else:
        print("\nThat was an invalid entry. Please try again.")
        miller_b_2() # runs function from beginning.  

# defining the function for the third play as Miller Bolaños
def miller_b_3():    
    print("""
It is now minute 85:50 of the match and you are winning 2-0.
You are standing by the center circle of the field with a defender over you,
and you see that your winger, Ángel "El Ángel del Gol" Mena, begins running
towards the penalty box...""")

    time.sleep(3) # pausing 3 seconds before advancing

    print("""Hurry! You have to start sprinting in order to reach the penalty box at the same time as Mena...""")
    
    # declaration of the variable used as a control on the while loop
    # loop used to control if input is not an integer number bigger than 0
    sprint_control_b = 1
    
    # importing random package to generate a different number of sprints each time
    import random
    
    # if the game is played multiple times, different number of sprints are expected
    rand_sprints_b = random.randint(a = 1, b = 4)
    
    while sprint_control_b > 0:
        
        # try/except inside loop to control input as an integer number bigger than 0
        try:
            sprints_b = int(input(prompt = """\nGuess how many times do you think you have to sprint?
Please enter an integer number between 1 and 4 (i.e. 1, 2, 3, 4).
Your number of sprints: """))
            
            if sprints_b == 0: # 0 is not a valid answer
                print("""\nUps, that was an invalid entry.
You must enter a integer number bigger than 0 between 1 and 4 (i.e. 1, 2, 3, 4).
Please try again""")
                continue # used to stay in the while function because an integer bigger than 0 is needed
            
            elif sprints_b == rand_sprints_b: # guess is correct
                sprint_control_b -= 1
            
                print(f"""\nGood you guessed correctly!
Now to sprint you have to press Enter/Intro {sprints_b} times:""")
            
                while sprints_b > 0: # loop to complete sprints
                    input(prompt = "Sprint!!!")
                    sprints_b -= 1
            
                break # to exit the while loop since sprints are complete, moves forward in the game
                
            elif sprints_b > 4: # controlling if guess is over maximum
                print(f"""\nThe maximum number of sprints is 4... So {sprints_b} is too high.
Please try again and enter an integer number between 1 and 4 (i.e. 1, 2, 3, 4).""")
                
            elif sprints_b < 0: # controlling if guess is under minimum
                print(f"""\nThe minimum number of sprints is 1... So {sprints_b} is too low and not even possible.
Please try again and enter an integer number between 1 and 4 (i.e. 1, 2, 3, 4).""")
            
            elif sprints_b < rand_sprints_b: # giving a hint to guess a bigger number
                print(f"""\nThat was close, but the number of sprints is bigger than {sprints_b}.
Please try again.""")
                
            elif sprints_b > rand_sprints_b: # giving a hint to guess a smaller number
                print(f"""\nThat was close, but the number of sprints is smaller than {sprints_b}.
Please try again.""")
        
        except: # for this project is not necessary to include the "ValueError", but for the future it could be used here
            print("""\nUps, that was an invalid entry.
You must enter an integer number between 1 and 4 (i.e. 1, 2, 3, 4).
Please try again""")
    
    print("""
Good!! You have entered the penalty box and and receive the ball from Ángel Mena.
You only have the goalkeeper in front of you. You must decide what to do...""")
       
    time.sleep(2) # pausing 2 seconds before advancing
    
    # variable for second Bolaños's goal
    goal_b_2 = input(prompt = """What do you do?\n
    a. Shoot right away.\n
    b. Dribble the goalkeeper and run to the goal line.\n
    c. Return the ball to your teammate.\n
    Your answer: """)
    
    if goal_b_2.lower() == 'a.' or goal_b_2.lower() == 'a' or 'shoot' in goal_b_2.lower() :
        print("""AMAZING!! You just scored a goal and the match is now 3-0""")
        
        # start a nested conditional to see if user wants to celebrate
        # while True used to bring user back to this point if they enter an invalid answer
        while True:                
            celebration_b = input(prompt = """Do you want to celebrate the goal?
a. Yes
b. No\n
Your answer: """)
            if celebration_b.lower() == 'a.' or celebration_b.lower() == 'a' or 'yes' in celebration_b.lower() or celebration_b.lower() == 'y' :
                import random
                
                celebration_option_b = random.randint(a = 1, b = 3)
                
                if celebration_option_b == 1:
                    print("""
                
 ██████   ██████   █████  ██      ██ ██ ██                   
██       ██    ██ ██   ██ ██      ██ ██ ██                   
██   ███ ██    ██ ███████ ██      ██ ██ ██                   
██    ██ ██    ██ ██   ██ ██                                 
 ██████   ██████  ██   ██ ███████ ██ ██ ██                   
                                                                                                                
                                                             
                                                             
███    ███ ██ ██      ██      ███████ ██████      ██████  ██ 
████  ████ ██ ██      ██      ██      ██   ██     ██   ██ ██ 
██ ████ ██ ██ ██      ██      █████   ██████      ██████  ██ 
██  ██  ██ ██ ██      ██      ██      ██   ██     ██   ██    
██      ██ ██ ███████ ███████ ███████ ██   ██     ██████  ██ 
                                                             
""")
                    
                elif celebration_option_b == 2:
                    print("""
   ____  ___   ___   ___  _       _____ ____   ___  __  __ 
  / ___|/ _ \ / _ \ / _ \| |     |  ___|  _ \ / _ \|  \/  |
 | |  _| | | | | | | | | | |     | |_  | |_) | | | | |\/| |
 | |_| | |_| | |_| | |_| | |___  |  _| |  _ <| |_| | |  | |
  \____|\___/ \___/ \___/|_____|_|_| _ |_| \_\\___/|_|  |_|
 | |/ /_ _| |   | |   | ____|  _ \  | |                    
 | ' / | || |   | |   |  _| | |_) | | |                    
 | . \ | || |___| |___| |___|  _ <  |_|                    
 |_|\_\___|_____|_____|_____|_| \_\ (_)                    
                                                           
""")
                    
                elif celebration_option_b == 3:
                    print("""
   __________  __       __________  __       __________  __       ______
  / ____/ __ \/ /      / ____/ __ \/ /      / ____/ __ \/ /      / / / /
 / / __/ / / / /      / / __/ / / / /      / / __/ / / / /      / / / / 
/ /_/ / /_/ / /___   / /_/ / /_/ / /___   / /_/ / /_/ / /___   /_/_/_/  
\____/\____/_____/   \____/\____/_____/   \____/\____/_____/  (_|_|_)   
   /  |/  /  _/ /   / /   / ____/ __ \   / / / /                        
  / /|_/ // // /   / /   / __/ / /_/ /  / / / /                         
 / /  / // // /___/ /___/ /___/ _, _/  /_/_/_/                          
/_/  /_/___/_____/_____/_____/_/ |_|  (_|_|_)                           
                                                                        
""")
                    
                else:
                    print("Something went wrong, please answer the question again.")
                    continue             
                
                game_summary()
                break # takes the game to the next and final stage after celebrating.
            
            elif celebration_b.lower() == 'b.' or celebration_b.lower() == 'b' or 'no' in celebration_b.lower() or celebration_b.lower() == 'n' :
                print("That's ok, the fans understand that you have given all of your effort and that you are really tired.")
                game_summary()
                break # takes the game to the next stage without celebrating.
        
            else:
                print("""\nThat was an invalid entry. Please try again.
It is ok if you only enter letters as "a" or "b".\n""")
                continue # ask user again if they want to celebrate until they get a correct answer.
                
        # end of nested conditional
    
    elif goal_b_2.lower() == 'b.' or goal_b_2.lower() == 'b' or 'dribble' in goal_b_2.lower() or 'run' in goal_b_2.lower():
        print("""
You fail in your attempt and the goalkeeper gets the ball and rapidly plays with his teammates,
and they score a goal.
        
Everybody on your team blames you for this goal and you lose your mind and hit
a player from the other team and you get a red card.

The rival team manages to score 2 goals in the last five minutes.
The game ends 2-2 and it goes to a penalty shootout.
However, your team is too nervous and you lose the game.""")
        fail() # player loses the game
        
    elif goal_b_2.lower() == 'c.' or goal_b_2.lower() == 'c' or 'return' in goal_b_2.lower() or 'teammate' in goal_b_2.lower():
        print("""
The goalkeeper intercepts your pass and rapidly plays with his teammates, and they score a goal.
Later they score the tying goal, and another goal and you lose the game.
        """)
        fail() # player loses the game
        
    else:
        print("""\nThat was an invalid entry. Please try again.
But, because you didn't enter a valid answer the game has decided to make you sprint again...
Just to make you get the emotion again!""") # the line break at the beginning gives me a nice organization of the text
        
        time.sleep(2) # pausing 2 seconds before advancing
        miller_b_3() # runs function again from beginning.  
        
# defining function were the user ends everytime he/she loses the game.        
def fail():
    
    time.sleep(1) # pausing 1 second before advancing
    
    print("""
  _____                _             _                            __
 | ____|_ __ ___   ___| | ___  ___  | | ___  ___  ___  ___   _   / /
 |  _| | '_ ` _ \ / _ \ |/ _ \/ __| | |/ _ \/ __|/ _ \/ __| (_) | | 
 | |___| | | | | |  __/ |  __/ (__  | | (_) \__ \  __/\__ \  _  | | 
 |_____|_| |_| |_|\___|_|\___|\___| |_|\___/|___/\___||___/ (_) | | 
                                                                 \_\\
""")
    
    # variable to let the user decide to start again the game or finish it.
    start_again = input(prompt = """Do you want to play again?\n
a. Yes

b. No\n
Your answer: """)
    
    if start_again.lower() == 'a.' or start_again.lower() == 'a' or 'yes' in start_again.lower() or start_again.lower() == 'y' :
        player_selection()
    
    elif start_again.lower() == 'b.' or start_again.lower() == 'b' or 'no' in start_again.lower() or start_again.lower() == 'n' :
        print('Thank you for playing :)')
        
    else:
        print("\nThat was an invalid entry. Please try again.")
        time.sleep(1) # pausing 1 second before advancing
        fail() # runs function again from beginning.
    
# defining function were the user ends if they win the game! This is the last function defined
def game_summary():
    time.sleep(2) # pausing 2 seconds before advancing
        
    input(prompt = """The referee blows the whistle, and the match is over!!
  _____ __  __ _____ _     _____ ____                        
 | ____|  \/  | ____| |   | ____/ ___|                       
 |  _| | |\/| |  _| | |   |  _|| |                           
 | |___| |  | | |___| |___| |__| |___                        
 |_____|_|  |_|_____|_____|_____\____|  
 
   ____ _   _    _    __  __ ____ ___ ___  _   _   _   _   _ 
  / ___| | | |  / \  |  \/  |  _ \_ _/ _ \| \ | | | | | | | |
 | |   | |_| | / _ \ | |\/| | |_) | | | | |  \| | | | | | | |
 | |___|  _  |/ ___ \| |  | |  __/| | |_| | |\  | |_| |_| |_|
  \____|_| |_/_/   \_\_|  |_|_|  |___\___/|_| \_| (_) (_) (_)
                                                             

Press Enter/Intro to give a score to your players.\n""")
    
    # declaration of the variable used as a control on the while loop
    # loop used to control if input is not an integer number bigger than 0 and smaller than 10
    score_control_m = 1
     
    # try/except inside loop to control input as an integer number bigger than 0 and smaller than 10.
    while score_control_m > 0:
        try:
            score_m = int(input(prompt = 'Enter the score between 1 and 10 for Ángel "El ángel del gol" Mena:\t'))
            
            if score_m == 0: # 0 is not a valid answer
                print("""\nThat wasn't a valid entry. Please enter an integer
number bigger than 0.
Plase try again.""")
                continue # used to stay in the while loop because an integer bigger than 0 is needed
                
            if score_m > 10: # any number over 10 is not accepted, this helps me control that
                print ("""\nThat wasn't a valid entry. Please enter a number
between 1 and 10. Your number was too high.
Please try again.""")
                continue # used to stay in the while loop because an integer smaller than 10 is needed
            
            score_control_m -= 1
            break  # to exit the while loop because a number between 1 and 10 is received.
            
        except: # type related errors end up here for this while True loop
            print("""\nThat wasn't a valid entry. Please enter an integer
number between 1 and 10, don't use text.
Please try again.""")
    
    # declaration of the variable used as a control on the while loop
    # loop used to control if input is not an integer number bigger than 0 and smaller than 10
    score_control_b = 1

    # try/except inside loop to control input as an integer number bigger than 0 and smaller than 10.
    while score_control_b > 0:
        try:
            score_b = int(input(prompt = 'Enter the score between 1 and 10 for Miller "Killer" Bolaños:\t'))
            
            if score_b == 0: # 0 is not a valid answer
                print("""\nThat wasn't a valid entry. Please enter an integer
number bigger than 0.
Plase try again.""")
                continue # used to stay in the while loop because an integer bigger than 0 is needed
                
            if score_b > 10: # any number over 10 is not accepted, this helps me control that
                print("""\nThat wasn't a valid entry. Please enter a number
between 1 and 10. Your number was too high.
Please try again.""")
                continue # used to stay in the while loop because an integer smaller than 10 is needed
            
            score_control_b -= 1
            break # to exit the while loop because a number between 1 and 10 is received.
            
        except: # type related errors end up here for this while True loop
            print("""\nThat wasn't a valid entry. Please enter an integer
number between 1 and 10, don't use text.""")
    
    input(prompt = "Please press Enter/Intro to see the highlights of the match.\n")
        
    # game highlights that will be printed at the end of the game.
    game_summary = [['Ángel "El ángel del gol" Mena', 'Goal at minute 20:30 (assist from Miller)',
                     'Assist at minute 80:00 (goal by Miller)', 'Assist at minute 85:50 (goal by Miller)'],
                    ['Miller "Killer" Bolaños', "Assist at minute 20:30 (goal by Mena)",
                     'Goal at minute 80:00 (assist from Mena)', 'Goal at minute 85:50 (assist from Mena)']]
    
    print('Match highlights:')
    
    # print all elements of the list by having first the players names and then the highlights
    # for loop used to print everything in one single call, useful if the list is updated or made dynamic in the future
    for name, one, two, three in game_summary: 
        print("\nPlayer: " + name + "\n " + one + "\n " + two + "\n " + three)
        
    print(f"""\n\nBased on these highlights the score for each player is:
    
Ángel "El ángel del gol" Mena: {score_m} points out of 10!!!
    
Miller "Killer" Bolaños: {score_b} points out of 10!!!\n
    """) # including dynamic printing of the scores
        
    time.sleep(3) # pausing 3 seconds before advancing
    
    # loop to let the player decide if they want to start the game again or finish it.
    # while true used to control if the player enters something that is not valid
    # so that the gamme_summary() function is not run again from the beginnig.
    while True:
        play_again = input(prompt = """\nYou won the game, do you want to play again?\n
a. Yes

b. No\n
Your answer: """)
    
        if play_again.lower() == 'a.' or play_again.lower() == 'a' or 'yes' in play_again.lower() or play_again.lower() == 'y' :
            player_selection() # starts the game again from the first function
            break # leaves the while loop and goes to the player_selection() function
    
        elif play_again.lower() == 'b.' or play_again.lower() == 'b' or 'no' in play_again.lower() or play_again.lower() == 'n' :
            print('Thank you for playing :)')
            break # exits the while loop and finishes the game 
        
        else:
            print("""\nThat was an invalid entry. Please try again.
It is ok if you only enter letters as "a." or "b."\n""")
            continue # ask the user again if they want to play again and provides
                     # instructions about the expected answer
    
player_selection()
# Out:
# Dear player, thank you for joining the “The Match of the Century” game.
# In this game you will represent one of the two MVPs of Emelec to recreate the
# most iconic plays of the second leg played in the final between Barcelona and
# Emelec in the year 2014 at "Estadio Capwell".
#
# To complete this game, you must win by a score of 3-0 and become the champion
# of the 2014 Ecuadorean tournament!!
#
# Good luck :)
# First you need to select a player to try to win this match!
#
# Please press Enter/Intro to begin
#
# Please select your player:
#     a. Ángel "El ángel del gol" Mena -- Position: Winger
#     b. Miller "Killer" Bolaños       -- Position: Center Forward
#     Your answer: b
#
# Great choice!
# You will be playing as Miller "Killer" Bolaños.
# Center Forward from Club Sport Emelec.
#
# It is minute 20:30 of the match and you see your attacking midfielder running
# towards the penalty box and your winger already at the penalty box with a
# defender right over him.
# ...
